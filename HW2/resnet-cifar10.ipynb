# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import torch.nn as nn
import torch.nn.functional as F

class ResNet20(nn.Module):
    def __init__(self, num_classes=10):
        super(ResNet20, self).__init__()
        n = 3  # (6n+2 = 20)
        

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)

        self.layer1 = self._make_layer(16, 16, n)

        self.layer2 = self._make_layer(16, 32, n, stride=2)

        self.layer3 = self._make_layer(32, 64, n, stride=2)
        
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(64, num_classes)

    def _make_layer(self, in_channels, out_channels, num_blocks, stride=1):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(ResBlock(in_channels, out_channels, stride))
            in_channels = out_channels
        return nn.Sequential(*layers)
    
    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        
        x = self.layer1(x)  # 32x32
        x = self.layer2(x)  # 16x16
        x = self.layer3(x)  # 8x8
        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, 
                              stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.dropout1 = nn.Dropout(0.1)
        
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3,
                              stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.dropout2 = nn.Dropout(0.1)
        
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1,
                         stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )
    
    def forward(self, x):
        out = self.dropout1(F.relu(self.bn1(self.conv1(x))))
        out = self.bn2(self.conv2(out))
        out = self.dropout2(out)
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ### Question (b)
# For the question, you need to:
# 1. Complete the preprocessing code below.
# 2. **In the PDF report**, briefly describe what preprocessing operations you used and what are the purposes of them.
#
# Hint:
# 1. Only two operations are necessary to complete the basic preprocessing here.
# 2. The raw input read from the dataset will be PIL images.
# 3. Data augmentation operations are not mendatory, but feel free to incorporate them if you want.
# 4. Reference value for mean/std of CIFAR-10 images (assuming the pixel values are within [0,1]): mean (RGB-format): (0.4914, 0.4822, 0.4465), std (RGB-format): (0.2023, 0.1994, 0.2010)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
# specify preprocessing function
transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=(0.4914, 0.4822, 0.4465),
        std=(0.2023, 0.1994, 0.2010)
    ),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip()
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=(0.4914, 0.4822, 0.4465),
        std=(0.2023, 0.1994, 0.2010)
    )
])
#############################################

# %% [markdown]
# ## Step 2: Set up dataset and dataloader
#
# ### Question (c)
# Set up the train/val datasets and dataloders that are to be used during the training. Check out the [official API](https://pytorch.org/docs/stable/data.html) for more information about **torch.utils.data.DataLoader**.
#
# Here, you need to:
# 1. Complete the code below.

# %%
# do NOT change these
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT, 
    mode='train', 
    download=True,
    transform=transform_train    # your code
)
val_set = CIFAR10(
    root=DATA_ROOT, 
    mode='val', 
    download=True,
    transform=transform_val    # your code
)

# construct dataloader
train_loader = DataLoader(
    train_set, 
    batch_size=TRAIN_BATCH_SIZE,  # your code
    shuffle=True,     # your code
    num_workers=4
)
val_loader = DataLoader(
    val_set, 
    batch_size=VAL_BATCH_SIZE,  # your code
    shuffle=False,     # your code
    num_workers=4
)
#############################################
# Out:
# Using downloaded and verified file: ./data\cifar10_trainval_F22.zip
# Extracting ./data\cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data\cifar10_trainval_F22.zip
# Extracting ./data\cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# specify the device for computation
#############################################
# your code here

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = ResNet20().to(device)
print(f"Using device: {device}")
    
#############################################
# Out:
# Using device: cuda

# %% [markdown]
# ## Step 4: Set up the loss function and optimizer
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.1

# momentum for optimizer
MOMENTUM = 0.9  

# L2 regularization strength
REG = 1e-4
MILESTONES = [25, 38]
DECAY = 0.2
#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss()

# Add optimizer
optimizer = optim.SGD(
    net.parameters(), 
    lr=INITIAL_LR, 
    momentum=MOMENTUM, 
    weight_decay=REG
)

scheduler = optim.lr_scheduler.MultiStepLR(
    optimizer, 
    milestones=MILESTONES,
    gamma=DECAY
)
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
#
# Here you need to:
# 1. Complete the training codes.
# 2. Actually perform the training.
#
# Hint: Training a neural network usually repeats the following 4 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the outputs from the neural network and compute the loss. Be careful about your inputs to the loss function. Are the inputs required to be the logits or softmax probabilities?)**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %%
# some hyperparameters
# total number of training epochs
EPOCHS = 60

# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):    
    #######################
    # your code here
    # switch to train mode
    net.train()
    
    #######################
    
    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want
    
    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs, targets = inputs.to(device), targets.to(device)
        
        # compute the output and loss
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        train_loss += loss.item()
        # zero the gradient
        optimizer.zero_grad()
        
        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly predicted samples in the current batch
        _, predicted = outputs.max(1)
        total_examples += targets.size(0)
        correct_examples += predicted.eq(targets).sum().item()
        ####################################
                
    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()
    
    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0
    
    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs, targets = inputs.to(device), targets.to(device)
            
            # compute the output and loss
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()

            
            # count the number of correctly predicted samples in the current batch
            _, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets).sum().item()  
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    scheduler.step()
    current_lr = scheduler.get_last_lr()[0]
    if i in MILESTONES:
        print(f"Learning rate decreased to {current_lr}")
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_FOLDER):
            os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'resnet200.pth'))
        
    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.6878, Training accuracy: 0.3670
# Validation loss: 2.1245, Validation accuracy: 0.3602
# Saving ...
#
# Epoch 1:
# Training loss: 1.2114, Training accuracy: 0.5643
# Validation loss: 1.1739, Validation accuracy: 0.5924
# Saving ...
#
# Epoch 2:
# Training loss: 0.9890, Training accuracy: 0.6452
# Validation loss: 0.8621, Validation accuracy: 0.6894
# Saving ...
#
# Epoch 3:
# Training loss: 0.8478, Training accuracy: 0.7012
# Validation loss: 0.8123, Validation accuracy: 0.7156
# Saving ...
#
# Epoch 4:
# Training loss: 0.7622, Training accuracy: 0.7337
# Validation loss: 0.7489, Validation accuracy: 0.7356
# Saving ...
#
# Epoch 5:
# Training loss: 0.6978, Training accuracy: 0.7570
# Validation loss: 0.7674, Validation accuracy: 0.7448
# Saving ...
#
# Epoch 6:
# Training loss: 0.6554, Training accuracy: 0.7722
# Validation loss: 0.6406, Validation accuracy: 0.7786
# Saving ...
#
# Epoch 7:
# Training loss: 0.6164, Training accuracy: 0.7844
# Validation loss: 0.5920, Validation accuracy: 0.7948
# Saving ...
#
# Epoch 8:
# Training loss: 0.5884, Training accuracy: 0.7956
# Validation loss: 0.6251, Validation accuracy: 0.7910
#
# Epoch 9:
# Training loss: 0.5625, Training accuracy: 0.8053
# Validation loss: 0.5714, Validation accuracy: 0.8138
# Saving ...
#
# Epoch 10:
# Training loss: 0.5460, Training accuracy: 0.8105
# Validation loss: 0.5858, Validation accuracy: 0.7972
#
# Epoch 11:
# Training loss: 0.5249, Training accuracy: 0.8190
# Validation loss: 0.5266, Validation accuracy: 0.8234
# Saving ...
#
# Epoch 12:
# Training loss: 0.5105, Training accuracy: 0.8229
# Validation loss: 0.5621, Validation accuracy: 0.8204
#
# Epoch 13:
# Training loss: 0.5028, Training accuracy: 0.8262
# Validation loss: 0.5239, Validation accuracy: 0.8294
# Saving ...
#
# Epoch 14:
# Training loss: 0.4871, Training accuracy: 0.8329
# Validation loss: 0.5349, Validation accuracy: 0.8162
#
# Epoch 15:
# Training loss: 0.4757, Training accuracy: 0.8355
# Validation loss: 0.4993, Validation accuracy: 0.8356
# Saving ...
#
# Epoch 16:
# Training loss: 0.4634, Training accuracy: 0.8397
# Validation loss: 0.5932, Validation accuracy: 0.7986
#
# Epoch 17:
# Training loss: 0.4596, Training accuracy: 0.8405
# Validation loss: 0.4545, Validation accuracy: 0.8508
# Saving ...
#
# Epoch 18:
# Training loss: 0.4462, Training accuracy: 0.8446
# Validation loss: 0.4839, Validation accuracy: 0.8396
#
# Epoch 19:
# Training loss: 0.4467, Training accuracy: 0.8450
# Validation loss: 0.5576, Validation accuracy: 0.8146
#
# Epoch 20:
# Training loss: 0.4301, Training accuracy: 0.8509
# Validation loss: 0.4689, Validation accuracy: 0.8376
#
# Epoch 21:
# Training loss: 0.4282, Training accuracy: 0.8505
# Validation loss: 0.4515, Validation accuracy: 0.8500
#
# Epoch 22:
# Training loss: 0.4237, Training accuracy: 0.8520
# Validation loss: 0.5031, Validation accuracy: 0.8316
#
# Epoch 23:
# Training loss: 0.4104, Training accuracy: 0.8572
# Validation loss: 0.4474, Validation accuracy: 0.8430
#
# Epoch 24:
# Training loss: 0.4063, Training accuracy: 0.8590
# Validation loss: 0.4143, Validation accuracy: 0.8596
# Saving ...
#
# Epoch 25:
# Training loss: 0.3212, Training accuracy: 0.8880
# Learning rate decreased to 0.020000000000000004
# Validation loss: 0.3221, Validation accuracy: 0.8870
# Saving ...
#
# Epoch 26:
# Training loss: 0.2983, Training accuracy: 0.8956
# Validation loss: 0.3223, Validation accuracy: 0.8906
# Saving ...
#
# Epoch 27:
# Training loss: 0.2893, Training accuracy: 0.9002
# Validation loss: 0.3120, Validation accuracy: 0.8960
# Saving ...
#
# Epoch 28:
# Training loss: 0.2825, Training accuracy: 0.9021
# Validation loss: 0.3214, Validation accuracy: 0.8886
#
# Epoch 29:
# Training loss: 0.2775, Training accuracy: 0.9020
# Validation loss: 0.3250, Validation accuracy: 0.8900
#
# Epoch 30:
# Training loss: 0.2722, Training accuracy: 0.9053
# Validation loss: 0.3229, Validation accuracy: 0.8900
#
# Epoch 31:
# Training loss: 0.2682, Training accuracy: 0.9072
# Validation loss: 0.3140, Validation accuracy: 0.8930
#
# Epoch 32:
# Training loss: 0.2671, Training accuracy: 0.9063
# Validation loss: 0.3273, Validation accuracy: 0.8912
#
# Epoch 33:
# Training loss: 0.2594, Training accuracy: 0.9095
# Validation loss: 0.3117, Validation accuracy: 0.8966
# Saving ...
#
# Epoch 34:
# Training loss: 0.2571, Training accuracy: 0.9103
# Validation loss: 0.3154, Validation accuracy: 0.8944
#
# Epoch 35:
# Training loss: 0.2533, Training accuracy: 0.9114
# Validation loss: 0.3164, Validation accuracy: 0.8964
#
# Epoch 36:
# Training loss: 0.2547, Training accuracy: 0.9110
# Validation loss: 0.3122, Validation accuracy: 0.8946
#
# Epoch 37:
# Training loss: 0.2480, Training accuracy: 0.9124
# Validation loss: 0.3160, Validation accuracy: 0.8982
# Saving ...
#
# Epoch 38:
# Training loss: 0.2276, Training accuracy: 0.9211
# Learning rate decreased to 0.004000000000000001
# Validation loss: 0.2901, Validation accuracy: 0.9016
# Saving ...
#
# Epoch 39:
# Training loss: 0.2210, Training accuracy: 0.9230
# Validation loss: 0.2914, Validation accuracy: 0.9024
# Saving ...
#
# Epoch 40:
# Training loss: 0.2200, Training accuracy: 0.9237
# Validation loss: 0.2890, Validation accuracy: 0.9038
# Saving ...
#
# Epoch 41:
# Training loss: 0.2153, Training accuracy: 0.9252
# Validation loss: 0.2892, Validation accuracy: 0.9048
# Saving ...
#
# Epoch 42:
# Training loss: 0.2157, Training accuracy: 0.9239
# Validation loss: 0.2878, Validation accuracy: 0.9044
#
# Epoch 43:
# Training loss: 0.2146, Training accuracy: 0.9256
# Validation loss: 0.2902, Validation accuracy: 0.9032
#
# Epoch 44:
# Training loss: 0.2139, Training accuracy: 0.9260
# Validation loss: 0.2891, Validation accuracy: 0.9028
#
# Epoch 45:
# Training loss: 0.2100, Training accuracy: 0.9259
# Validation loss: 0.2895, Validation accuracy: 0.9046
#
# Epoch 46:
# Training loss: 0.2097, Training accuracy: 0.9259
# Validation loss: 0.2889, Validation accuracy: 0.9070
# Saving ...
#
# Epoch 47:
# Training loss: 0.2062, Training accuracy: 0.9282
# Validation loss: 0.2889, Validation accuracy: 0.9040
#
# Epoch 48:
# Training loss: 0.2093, Training accuracy: 0.9260
# Validation loss: 0.2907, Validation accuracy: 0.9054
#
# Epoch 49:
# Training loss: 0.2076, Training accuracy: 0.9273
# Validation loss: 0.2888, Validation accuracy: 0.9076
# Saving ...
#
# Epoch 50:
# Training loss: 0.2064, Training accuracy: 0.9279
# Validation loss: 0.2925, Validation accuracy: 0.9066
#
# Epoch 51:
# Training loss: 0.2086, Training accuracy: 0.9262
# Validation loss: 0.2877, Validation accuracy: 0.9076
#
# Epoch 52:
# Training loss: 0.2045, Training accuracy: 0.9274
# Validation loss: 0.2870, Validation accuracy: 0.9072
#
# Epoch 53:
# Training loss: 0.2047, Training accuracy: 0.9277
# Validation loss: 0.2899, Validation accuracy: 0.9054
#
# Epoch 54:
# Training loss: 0.2030, Training accuracy: 0.9283
# Validation loss: 0.2937, Validation accuracy: 0.9042
#
# Epoch 55:
# Training loss: 0.2006, Training accuracy: 0.9289
# Validation loss: 0.2910, Validation accuracy: 0.9036
#
# Epoch 56:
# Training loss: 0.2028, Training accuracy: 0.9284
# Validation loss: 0.2898, Validation accuracy: 0.9046
#
# Epoch 57:
# Training loss: 0.1982, Training accuracy: 0.9307
# Validation loss: 0.2893, Validation accuracy: 0.9060
#
# Epoch 58:
# Training loss: 0.1970, Training accuracy: 0.9306
# Validation loss: 0.2909, Validation accuracy: 0.9072
#
# Epoch 59:
# Training loss: 0.1979, Training accuracy: 0.9302
# Validation loss: 0.2901, Validation accuracy: 0.9040
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9076
