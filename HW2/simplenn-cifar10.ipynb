# %% [markdown]
# # Training SimpleNN on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the SimpleNN model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# define the SimpleNN mode;
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 8, 5)
        self.conv2 = nn.Conv2d(8, 16, 3)
        self.fc1   = nn.Linear(16*6*6, 120)
        self.fc2   = nn.Linear(120, 84)
        self.fc3   = nn.Linear(84, 10)

    def forward(self, x):
        out = F.relu(self.conv1(x))
        out = F.max_pool2d(out, 2)
        out = F.relu(self.conv2(out))
        out = F.max_pool2d(out, 2)
        out = out.view(out.size(0), -1)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        return out

# %% [markdown]
# ### Question (a)
# Here is a sanity check to verify the implementation of SimpleNN.
# You need to:
# 1. Write down your code.
# 2. **In the PDF report**, give a brief description on how the code helps you know that SimpleNN is implemented correctly.

# %%
#############################################
# your code here
# sanity check for the correctness of SimpleNN


def test_simple_nn_shape():
    net = SimpleNN()
    x = torch.randn(1, 3, 32, 32)
    y = net(x)
    assert y.shape == (1, 10), f"Expected output shape (1, 10), but got {y.shape}"
    print("SimpleNN shape test passed!")

def test_simple_nn_param():
    net = SimpleNN()
    total_params = sum(p.numel() for p in net.parameters() if p.requires_grad)
    assert total_params == 82030, f"Expected 82030 parameters, but got {total_params}"
    print("SimpleNN #param test passed!")
test_simple_nn_shape()
test_simple_nn_param()
#############################################
# Out:
# SimpleNN shape test passed!
# SimpleNN #param test passed!

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ### Question (b)
# For the question, you need to:
# 1. Complete the preprocessing code below.
# 2. **In the PDF report**, briefly describe what preprocessing operations you used and what are the purposes of them.
#
# Hint:
# 1. Only two operations are necessary to complete the basic preprocessing here.
# 2. The raw input read from the dataset will be PIL images.
# 3. Data augmentation operations are not mendatory, but feel free to incorporate them if you want.
# 4. Reference value for mean/std of CIFAR-10 images (assuming the pixel values are within [0,1]): mean (RGB-format): (0.4914, 0.4822, 0.4465), std (RGB-format): (0.2023, 0.1994, 0.2010)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
# specify preprocessing function
transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=(0.4914, 0.4822, 0.4465),
        std=(0.2023, 0.1994, 0.2010)
    )
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=(0.4914, 0.4822, 0.4465),
        std=(0.2023, 0.1994, 0.2010)
    )
])
#############################################

# %% [markdown]
# ## Step 2: Set up dataset and dataloader
#
# ### Question (c)
# Set up the train/val datasets and dataloders that are to be used during the training. Check out the [official API](https://pytorch.org/docs/stable/data.html) for more information about **torch.utils.data.DataLoader**.
#
# Here, you need to:
# 1. Complete the code below.

# %%
# do NOT change these
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT, 
    mode='train', 
    download=True,
    transform=transform_train    # your code
)
val_set = CIFAR10(
    root=DATA_ROOT, 
    mode='val', 
    download=True,
    transform=transform_val    # your code
)

# construct dataloader
train_loader = DataLoader(
    train_set, 
    batch_size=TRAIN_BATCH_SIZE,  # your code
    shuffle=True,     # your code
    num_workers=4
)
val_loader = DataLoader(
    val_set, 
    batch_size=VAL_BATCH_SIZE,  # your code
    shuffle=False,     # your code
    num_workers=4
)
#############################################
# Out:
# Using downloaded and verified file: ./data\cifar10_trainval_F22.zip
# Extracting ./data\cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data\cifar10_trainval_F22.zip
# Extracting ./data\cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# specify the device for computation
#############################################
# your code here

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = SimpleNN().to(device)
print(f"Using device: {device}")
    
#############################################
# Out:
# Using device: cuda

# %% [markdown]
# ## Step 4: Set up the loss function and optimizer
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.01

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-4

#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss()

# Add optimizer
optimizer = optim.SGD(
    net.parameters(), 
    lr=INITIAL_LR, 
    momentum=MOMENTUM, 
    weight_decay=REG
)
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
#
# Here you need to:
# 1. Complete the training codes.
# 2. Actually perform the training.
#
# Hint: Training a neural network usually repeats the following 4 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the outputs from the neural network and compute the loss. Be careful about your inputs to the loss function. Are the inputs required to be the logits or softmax probabilities?)**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %%
# some hyperparameters
# total number of training epochs
EPOCHS = 30

# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):    
    #######################
    # your code here
    # switch to train mode
    net.train()
    
    #######################
    
    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want
    
    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs, targets = inputs.to(device), targets.to(device)
        
        # compute the output and loss
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        train_loss += loss.item()
        # zero the gradient
        optimizer.zero_grad()
        
        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly predicted samples in the current batch
        _, predicted = outputs.max(1)
        total_examples += targets.size(0)
        correct_examples += predicted.eq(targets).sum().item()
        ####################################
                
    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()
    
    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0
    
    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs, targets = inputs.to(device), targets.to(device)
            
            # compute the output and loss
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
            # count the number of correctly predicted samples in the current batch
            _, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets).sum().item()  
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        #if not os.path.exists(CHECKPOINT_FOLDER):
        #    os.makedirs(CHECKPOINT_FOLDER)
        #print("Saving ...")
        #state = {'state_dict': net.state_dict(),
        #         'epoch': i,
        #         'lr': current_learning_rate}
        #torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'simplenn.pth'))
        
    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.8781, Training accuracy: 0.3142
# Validation loss: 1.5445, Validation accuracy: 0.4426
#
# Epoch 1:
# Training loss: 1.4076, Training accuracy: 0.4908
# Validation loss: 1.3227, Validation accuracy: 0.5302
#
# Epoch 2:
# Training loss: 1.2303, Training accuracy: 0.5583
# Validation loss: 1.2244, Validation accuracy: 0.5718
#
# Epoch 3:
# Training loss: 1.1271, Training accuracy: 0.6018
# Validation loss: 1.1485, Validation accuracy: 0.6010
#
# Epoch 4:
# Training loss: 1.0244, Training accuracy: 0.6382
# Validation loss: 1.1089, Validation accuracy: 0.6122
#
# Epoch 5:
# Training loss: 0.9497, Training accuracy: 0.6650
# Validation loss: 1.0612, Validation accuracy: 0.6302
#
# Epoch 6:
# Training loss: 0.8977, Training accuracy: 0.6846
# Validation loss: 1.1137, Validation accuracy: 0.6168
#
# Epoch 7:
# Training loss: 0.8495, Training accuracy: 0.7011
# Validation loss: 1.0569, Validation accuracy: 0.6352
#
# Epoch 8:
# Training loss: 0.7974, Training accuracy: 0.7184
# Validation loss: 1.0373, Validation accuracy: 0.6496
#
# Epoch 9:
# Training loss: 0.7487, Training accuracy: 0.7363
# Validation loss: 1.0531, Validation accuracy: 0.6456
#
# Epoch 10:
# Training loss: 0.7117, Training accuracy: 0.7476
# Validation loss: 1.0704, Validation accuracy: 0.6442
#
# Epoch 11:
# Training loss: 0.6676, Training accuracy: 0.7633
# Validation loss: 1.0516, Validation accuracy: 0.6576
#
# Epoch 12:
# Training loss: 0.6357, Training accuracy: 0.7743
# Validation loss: 1.0985, Validation accuracy: 0.6398
#
# Epoch 13:
# Training loss: 0.5985, Training accuracy: 0.7888
# Validation loss: 1.2192, Validation accuracy: 0.6248
#
# Epoch 14:
# Training loss: 0.5671, Training accuracy: 0.7977
# Validation loss: 1.1859, Validation accuracy: 0.6460
#
# Epoch 15:
# Training loss: 0.5383, Training accuracy: 0.8085
# Validation loss: 1.2600, Validation accuracy: 0.6342
#
# Epoch 16:
# Training loss: 0.5063, Training accuracy: 0.8188
# Validation loss: 1.2784, Validation accuracy: 0.6424
#
# Epoch 17:
# Training loss: 0.4788, Training accuracy: 0.8279
# Validation loss: 1.3339, Validation accuracy: 0.6376
#
# Epoch 18:
# Training loss: 0.4618, Training accuracy: 0.8355
# Validation loss: 1.3183, Validation accuracy: 0.6342
#
# Epoch 19:
# Training loss: 0.4298, Training accuracy: 0.8461
# Validation loss: 1.4137, Validation accuracy: 0.6394
#
# Epoch 20:
# Training loss: 0.4172, Training accuracy: 0.8493
# Validation loss: 1.4580, Validation accuracy: 0.6424
#
# Epoch 21:
# Training loss: 0.3816, Training accuracy: 0.8624
# Validation loss: 1.4741, Validation accuracy: 0.6406
#
# Epoch 22:
# Training loss: 0.3702, Training accuracy: 0.8672
# Validation loss: 1.5968, Validation accuracy: 0.6332
#
# Epoch 23:
# Training loss: 0.3670, Training accuracy: 0.8671
# Validation loss: 1.6323, Validation accuracy: 0.6356
#
# Epoch 24:
# Training loss: 0.3350, Training accuracy: 0.8784
# Validation loss: 1.7042, Validation accuracy: 0.6306
#
# Epoch 25:
# Training loss: 0.3228, Training accuracy: 0.8833
# Validation loss: 1.7822, Validation accuracy: 0.6230
#
# Epoch 26:
# Training loss: 0.3205, Training accuracy: 0.8852
# Validation loss: 1.7350, Validation accuracy: 0.6280
#
# Epoch 27:
# Training loss: 0.3182, Training accuracy: 0.8851
# Validation loss: 1.8814, Validation accuracy: 0.6204
#
# Epoch 28:
# Training loss: 0.2912, Training accuracy: 0.8953
# Validation loss: 1.8381, Validation accuracy: 0.6248
#
# Epoch 29:
# Training loss: 0.2865, Training accuracy: 0.8989
# Validation loss: 1.9087, Validation accuracy: 0.6286
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.6576

# %% [markdown]
# # Bonus: with learning rate decay
#
# The following code can help you adjust the learning rate during training. You need to figure out how to incorporate this code into your training loop.
# ```python
#     if i % DECAY_EPOCHS == 0 and i != 0:
#         current_learning_rate = current_learning_rate * DECAY
#         for param_group in optimizer.param_groups:
#             param_group['lr'] = current_learning_rate
#         print("Current learning rate has decayed to %f" %current_learning_rate)
# ```

# %%
# some hyperparameters
# total number of training epochs
EPOCHS = 30

# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"
# Learning rate decay parameters
DECAY_EPOCHS = 10  # Decay learning rate every 10 epochs
DECAY = 0.1        # Multiply learning rate by 0.1 when decaying

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):   
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate) 
    #######################
    # your code here
    # switch to train mode
    net.train()
    
    #######################
    
    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want
    
    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs, targets = inputs.to(device), targets.to(device)
        
        # compute the output and loss
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        
        # zero the gradient
        optimizer.zero_grad()
        
        # backpropagation
        loss.backward()
        
        # apply gradient and update the weights
        optimizer.step()
        
        # count the number of correctly predicted samples in the current batch
        _, predicted = outputs.max(1)
        total_examples += targets.size(0)
        correct_examples += predicted.eq(targets).sum().item()
        ####################################
                
    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    net.eval()
    
    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0
    
    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs, targets = inputs.to(device), targets.to(device)
            
            # compute the output and loss
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            
            # count the number of correctly predicted samples in the current batch
            _, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets).sum().item()  
            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        #if not os.path.exists(CHECKPOINT_FOLDER):
        #    os.makedirs(CHECKPOINT_FOLDER)
        #print("Saving ...")
        #state = {'state_dict': net.state_dict(),
        #         'epoch': i,
        #         'lr': current_learning_rate}
        #torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'simplenn.pth'))
        
    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 0.0000, Training accuracy: 0.3036
# Validation loss: 0.0000, Validation accuracy: 0.4342
#
# Epoch 1:
# Training loss: 0.0000, Training accuracy: 0.4808
# Validation loss: 0.0000, Validation accuracy: 0.5084
#
# Epoch 2:
# Training loss: 0.0000, Training accuracy: 0.5467
# Validation loss: 0.0000, Validation accuracy: 0.5584
#
# Epoch 3:
# Training loss: 0.0000, Training accuracy: 0.5998
# Validation loss: 0.0000, Validation accuracy: 0.5848
#
# Epoch 4:
# Training loss: 0.0000, Training accuracy: 0.6253
# Validation loss: 0.0000, Validation accuracy: 0.6128
#
# Epoch 5:
# Training loss: 0.0000, Training accuracy: 0.6532
# Validation loss: 0.0000, Validation accuracy: 0.6162
#
# Epoch 6:
# Training loss: 0.0000, Training accuracy: 0.6759
# Validation loss: 0.0000, Validation accuracy: 0.6354
#
# Epoch 7:
# Training loss: 0.0000, Training accuracy: 0.6984
# Validation loss: 0.0000, Validation accuracy: 0.6448
#
# Epoch 8:
# Training loss: 0.0000, Training accuracy: 0.7154
# Validation loss: 0.0000, Validation accuracy: 0.6462
#
# Epoch 9:
# Training loss: 0.0000, Training accuracy: 0.7285
# Validation loss: 0.0000, Validation accuracy: 0.6416
#
# Current learning rate has decayed to 0.001000
# Epoch 10:
# Training loss: 0.0000, Training accuracy: 0.7983
# Validation loss: 0.0000, Validation accuracy: 0.6738
#
# Epoch 11:
# Training loss: 0.0000, Training accuracy: 0.8112
# Validation loss: 0.0000, Validation accuracy: 0.6720
#
# Epoch 12:
# Training loss: 0.0000, Training accuracy: 0.8171
# Validation loss: 0.0000, Validation accuracy: 0.6794
#
# Epoch 13:
# Training loss: 0.0000, Training accuracy: 0.8224
# Validation loss: 0.0000, Validation accuracy: 0.6758
#
# Epoch 14:
# Training loss: 0.0000, Training accuracy: 0.8284
# Validation loss: 0.0000, Validation accuracy: 0.6702
#
# Epoch 15:
# Training loss: 0.0000, Training accuracy: 0.8329
# Validation loss: 0.0000, Validation accuracy: 0.6720
#
# Epoch 16:
# Training loss: 0.0000, Training accuracy: 0.8368
# Validation loss: 0.0000, Validation accuracy: 0.6732
#
# Epoch 17:
# Training loss: 0.0000, Training accuracy: 0.8415
# Validation loss: 0.0000, Validation accuracy: 0.6686
#
# Epoch 18:
# Training loss: 0.0000, Training accuracy: 0.8446
# Validation loss: 0.0000, Validation accuracy: 0.6688
#
# Epoch 19:
# Training loss: 0.0000, Training accuracy: 0.8501
# Validation loss: 0.0000, Validation accuracy: 0.6696
#
# Current learning rate has decayed to 0.000100
# Epoch 20:
# Training loss: 0.0000, Training accuracy: 0.8629
# Validation loss: 0.0000, Validation accuracy: 0.6712
#
# Epoch 21:
# Training loss: 0.0000, Training accuracy: 0.8648
# Validation loss: 0.0000, Validation accuracy: 0.6714
#
# Epoch 22:
# Training loss: 0.0000, Training accuracy: 0.8648
# Validation loss: 0.0000, Validation accuracy: 0.6698
#
# Epoch 23:
# Training loss: 0.0000, Training accuracy: 0.8655
# Validation loss: 0.0000, Validation accuracy: 0.6690
#
# Epoch 24:
# Training loss: 0.0000, Training accuracy: 0.8661
# Validation loss: 0.0000, Validation accuracy: 0.6708
#
# Epoch 25:
# Training loss: 0.0000, Training accuracy: 0.8670
# Validation loss: 0.0000, Validation accuracy: 0.6684
#
# Epoch 26:
# Training loss: 0.0000, Training accuracy: 0.8668
# Validation loss: 0.0000, Validation accuracy: 0.6692
#
# Epoch 27:
# Training loss: 0.0000, Training accuracy: 0.8673
# Validation loss: 0.0000, Validation accuracy: 0.6692
#
# Epoch 28:
# Training loss: 0.0000, Training accuracy: 0.8670
# Validation loss: 0.0000, Validation accuracy: 0.6696
#
# Epoch 29:
# Training loss: 0.0000, Training accuracy: 0.8683
# Validation loss: 0.0000, Validation accuracy: 0.6688
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.6794
